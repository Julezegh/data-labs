# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
# Paste the url you obtained for your data:
url= 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=sale'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
#1. Import libraries
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#2. Define the initial API endpoint URL
url= 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=sale'

# %%
#3. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.8) Gecko/20100722 Firefox/3.6.8 GTB7.1 (.NET CLR 3.5.30729)", "Referer": "http://example.com"}
response = requests.get(url, headers= headers, timeout=5)
results = response.json()
results
# Out:
# {'total_count': 97641,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'PU111S05F-Q13',
#    'name': 'VIKKY PLATFORM - Baskets basses - black/white/metallic gold',
#    'price': {'original': '65,00\xa0€',
#     'promotional': '25,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'puma-vikky-platform-baskets-basses-pu111s05f-q13',
#    'media': [{'path': 'PU/11/1S/05/FQ/13/PU111S05F-Q13@2.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-62%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'W93c4aFKSxe',
#      'url_key': '/outfits/W93c4aFKSxe',
#      'media': [{'path': 'b9797dad385d4a6eb3ca49ff337717de/c01b8c181b184046a0a2ee2fa718fbe1.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'ff8f35ca-0d93-4e77-8e02-48f633438c2e',
#       'name': 'shawnysander',
#       'media': [{'path': '17c9336be4b946c4affbadb904bb8633/cb1d2a17ec3b47b1b39849ef62bb71cf.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'RA254K015-O11'},
#       {'id': 'Y0121T01J-K11'},
#       {'id': 'PU111S05F-Q13'}]}]},
#   {'sku': 'AD121A096-Q11',
#    'name': 'TIGHT - Legging - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '22,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-leggings-black-ad121a096-q11',
#    'media': [{'path': 'AD/12/1A/09/6Q/11/AD121A096-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/09/6Q/11/AD121A096-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'LE221D033-A13',
#    'name': 'THE PERFECT - T-shirt imprimé - white',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levi-s-the-perfect-t-shirt-imprime-le221d033-a13',
#    'media': [{'path': 'LE/22/1D/03/3A/13/LE221D033-A13@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/03/3A/13/LE221D033-A13@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU111A094-A12',
#    'name': 'CALI - Baskets basses - white/black',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '41'],
#    'url_key': 'puma-cali-baskets-basses-pu111a094-a12',
#    'media': [{'path': 'PU/11/1A/09/4A/12/PU111A094-A12@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'CO411A00U-802',
#    'name': 'CHUCK TAYLOR ALL STAR HI - Baskets montantes - black',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '63,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '51.5',
#     '53'],
#    'url_key': 'converse-as-hi-can-baskets-noir-co411a00u-802',
#    'media': [{'path': 'CO/41/1A/00/U8/02/CO411A00U-802@19.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'rfLLFx33TLK',
#      'url_key': '/outfits/rfLLFx33TLK',
#      'media': [{'path': '7fe95c574be54877a02ebb1621d2f47a/0716ed43797342948a7809e91c914cbb.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'TP751B05Y-O11'},
#       {'id': 'WEB21T00X-Q11'},
#       {'id': 'PI851L0BZ-D11'},
#       {'id': 'CO411A00U-802'}]}]},
#   {'sku': 'PU111A0EB-Q11',
#    'name': "VIKKY RIBBON WOMEN'S TRAINERS  - Baskets basses - black",
#    'price': {'original': '60,00\xa0€',
#     'promotional': '25,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '37', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'puma-vikky-ribbon-womens-trainers-baskets-basses-pu111a0eb-q11',
#    'media': [{'path': 'PU/11/1A/0E/BQ/11/PU111A0EB-Q11@4.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-58%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'AD115O07M-A11',
#    'name': 'CONTINENTAL 80 - Baskets basses - footwear white/scarlet/collegiate navy',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-continental-baskets-basses-ad115o07m-a11',
#    'media': [{'path': 'AD/11/5O/07/MA/11/AD115O07M-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': '1FI11A004-A11',
#    'name': 'DISRUPTOR - Baskets basses - white',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'fila-disruptor-baskets-basses-1fi11a004-a11',
#    'media': [{'path': '1F/I1/1A/00/4A/11/1FI11A004-A11@13.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'AD121A0AE-Q11',
#    'name': 'TREFOIL TIGHT - Legging - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46', '48', '50'],
#    'url_key': 'adidas-originals-trefoil-tight-legging-ad121a0ae-q11',
#    'media': [{'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/0A/EQ/11/AD121A0AE-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'AD111A0PQ-A11',
#    'name': 'SLEEK - Baskets basses - footwear white/crystal white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3'],
#    'url_key': 'adidas-originals-sleek-baskets-basses-ad111a0pq-a11',
#    'media': [{'path': 'AD/11/1A/0P/QA/11/AD111A0PQ-A11@27.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'CO411A0BD-002',
#    'name': 'CHUCK TAYLOR ALL STAR HI - Baskets montantes - white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '63,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '49',
#     '50',
#     '51.5',
#     '53'],
#    'url_key': 'converse-baskets-montantes-blanc-co411a0bd-002',
#    'media': [{'path': 'CO/41/1A/0B/D0/02/CO411A0BD-002@118.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'ECSZIgIZRCW',
#      'url_key': '/outfits/ECSZIgIZRCW',
#      'media': [{'path': '67cc4884702c4ecd87ec118453ad48d1/33f399904be8450d9c3d1ab34716f049.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'M3T31E001-S13'},
#       {'id': 'SA321E04I-A11'},
#       {'id': 'DK151H0EQ-A11'},
#       {'id': 'TP751L0KU-O11'},
#       {'id': 'GP021B03F-K11'},
#       {'id': 'CO411A0BD-002'}]}]},
#   {'sku': 'LE221D022-A12',
#    'name': 'THE PERFECT - T-shirt imprimé - woodgrain batwing/white',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '18,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levi-s-the-perfect-t-shirt-imprime-le221d022-a12',
#    'media': [{'path': 'LE/22/1D/02/2A/12/LE221D022-A12@18.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/02/2A/12/LE221D022-A12@19.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU111A094-Q11',
#    'name': 'CALI - Baskets basses - black/white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5'],
#    'url_key': 'puma-cali-baskets-basses-blackwhite-pu111a094-q11',
#    'media': [{'path': 'PU/11/1A/09/4Q/11/PU111A094-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PU111A0BO-A11',
#    'name': 'CALI BOLD - Baskets basses - white/metallic gold',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '66,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'puma-cali-bold-baskets-basses-whitemetallic-gold-pu111a0bo-a11',
#    'media': [{'path': 'PU/11/1A/0B/OA/11/PU111A0BO-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-26%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'VA215A003-Q12',
#    'name': 'SK8-HI - Baskets montantes - black',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '72,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-sk8-baskets-montantes-va215a003-q12',
#    'media': [{'path': 'VA/21/5A/00/3Q/12/VA215A003-Q12@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'EL921A00S-Q11',
#    'name': 'SOLOS - Legging - anthracite',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'ellesse-solos-2-womens-leggings-el921a00s-q11',
#    'media': [{'path': 'EL/92/1A/00/SQ/11/EL921A00S-Q11@3.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EL/92/1A/00/SQ/11/EL921A00S-Q11@2.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Ellesse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NI121A07O-Q11',
#    'name': 'CLUB  - Legging - black/white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-club-legging-ni121a07o-q11',
#    'media': [{'path': 'NI/12/1A/07/OQ/11/NI121A07O-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/07/OQ/11/NI121A07O-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU141K011-Q11',
#    'name': 'CLASSIC SUIT - Survêtement - puma',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'puma-classic-suit-survetement-puma-pu141k011-q11',
#    'media': [{'path': 'PU/14/1K/01/1Q/11/PU141K011-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PU/14/1K/01/1Q/11/PU141K011-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'VA212Z002-802',
#    'name': 'AUTHENTIC - Baskets basses - black',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '55,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-authentic-baskets-noir-va212z002-802',
#    'media': [{'path': 'VA/21/2Z/00/28/02/VA212Z002-802@25.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'NE211A094-D11',
#    'name': 'GW500 - Baskets basses - metallic silver',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '52,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '41.5',
#     '42.5'],
#    'url_key': 'new-balance-gw500-baskets-basses-metallic-silver-ne211a094-d11',
#    'media': [{'path': 'NE/21/1A/09/4D/11/NE211A094-D11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Balance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'AN611E015-Q11',
#    'name': 'Derbies - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '24,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'anna-field-derbies-black-an611e015-q11',
#    'media': [{'path': 'AN/61/1E/01/5Q/11/AN611E015-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'LE221J02S-K11',
#    'name': 'UNBASIC HOODIE  - Sweat à capuche - xenon blue',
#    'price': {'original': '68,95\xa0€',
#     'promotional': '48,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-unbasic-hoodie-sweatshirt-xenon-blue-le221j02s-k11',
#    'media': [{'path': 'LE/22/1J/02/SK/11/LE221J02S-K11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1J/02/SK/11/LE221J02S-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NI111A084-Q11',
#    'name': 'AIR MAX 270 - Baskets basses - black',
#    'price': {'original': '149,95\xa0€',
#     'promotional': '134,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'nike-sportswear-air-max-270-baskets-basses-ni111a084-q11',
#    'media': [{'path': 'NI/11/1A/08/4Q/11/NI111A084-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe'},
#   {'sku': 'NI111S037-Q12',
#    'name': 'CLASSIC CORTEZ - Baskets basses - black/white',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '67,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43'],
#    'url_key': 'nike-sportswear-classic-cortez-baskets-basses-ni111s037-q12',
#    'media': [{'path': 'NI/11/1S/03/7Q/12/NI111S037-Q12@110.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'RE011S01A-A11',
#    'name': 'CLASSIC - Baskets basses - white/light grey',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '35.5',
#     '36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '44'],
#    'url_key': 'reebok-classic-baskets-basses-white-light-grey-re011s01a-a11',
#    'media': [{'path': 'RE/01/1S/01/AA/11/RE011S01A-A11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PU115O01A-Q12',
#    'name': 'SMASH V2 - Baskets basses - black/white/silver',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '40,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '46'],
#    'url_key': 'puma-smash-baskets-basses-pu115o01a-q12',
#    'media': [{'path': 'PU/11/5O/01/AQ/12/PU115O01A-Q12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'V1021U00B-C11',
#    'name': 'VICAMA NEW - Manteau classique - light grey melange/black',
#    'price': {'original': '139,99\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL'],
#    'url_key': 'vila-vicama-new-manteau-classique-v1021u00b-c11',
#    'media': [{'path': 'V1/02/1U/00/BC/11/V1021U00B-C11@31.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1U/00/BC/11/V1021U00B-C11@36.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'EV411N045-Q11',
#    'name': 'Bottines à lacets - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '25,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'evenandodd-bottines-a-lacets-black-ev411n045-q11',
#    'media': [{'path': 'EV/41/1N/04/5Q/11/EV411N045-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'NI121A09Q-Q11',
#    'name': 'LEGASEE FLIP - Legging - black/racer blue',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '31,46\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-legasee-legging-blackracer-blue-ni121a09q-q11',
#    'media': [{'path': 'NI/12/1A/09/QQ/11/NI121A09Q-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/09/QQ/11/NI121A09Q-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'CO411A003-802',
#    'name': 'CHUCK TAYLOR ALL STAR OX - Baskets basses - black',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '55,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '51.5',
#     '53',
#     '54'],
#    'url_key': 'converse-as-ox-can-baskets-noir-co411a003-802',
#    'media': [{'path': 'CO/41/1A/00/38/02/CO411A003-802@19.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'OtShp0unSPm',
#      'url_key': '/outfits/OtShp0unSPm',
#      'media': [{'path': '952b26c8d9e64e99af7fc4b6c15b3d39/7f475c0548a7483bb6679a8804f92692.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'women',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'Q0151K018-Q11'},
#       {'id': 'PY021G00F-Q11'},
#       {'id': 'NM321E08X-Q11'},
#       {'id': 'A0Q51H01W-Q11'},
#       {'id': 'PI851L0BZ-D11'},
#       {'id': 'TQ021C024-K11'},
#       {'id': 'CO411A003-802'}]}]},
#   {'sku': 'PU111A0BI-A11',
#    'name': 'CALI - Baskets basses - white/black',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5'],
#    'url_key': 'puma-cali-baskets-basses-whiteblack-pu111a0bi-a11',
#    'media': [{'path': 'PU/11/1A/0B/IA/11/PU111A0BI-A11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PU111A0DP-A11',
#    'name': 'Baskets basses - white',
#    'price': {'original': '90,00\xa0€',
#     'promotional': '63,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41'],
#    'url_key': 'puma-baskets-basses-white-pu111a0dp-a11',
#    'media': [{'path': 'PU/11/1A/0D/PA/11/PU111A0DP-A11@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'NL011A0LH-F11',
#    'name': 'FIESTA - Mules - rose gold',
#    'price': {'original': '14,99\xa0€',
#     'promotional': '9,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'new-look-fiesta-mules-rose-gold-nl011a0lh-f11',
#    'media': [{'path': 'NL/01/1A/0L/HF/11/NL011A0LH-F11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Look',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'AD112B0M0-K11',
#    'name': 'CAMPUS - Baskets basses - dark blue/white/chalk white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-campus-baskets-basses-dark-bluewhitechalk-white-ad112b0m0-k11',
#    'media': [{'path': 'AD/11/2B/0M/0K/11/AD112B0M0-K11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe'},
#   {'sku': 'NI121A05R-Q11',
#    'name': 'CLUB LOGO - Legging - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '19,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'nike-sportswear-club-logo2-leggings-ni121a05r-q11',
#    'media': [{'path': 'NI/12/1A/05/RQ/11/NI121A05R-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/1A/05/RQ/11/NI121A05R-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'LE221S00T-K12',
#    'name': '501® - Short en jean - blue clue',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '38,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['24', '25', '26', '27', '28', '29', '30'],
#    'url_key': 'levisr-501r-short-en-jean-blue-clue-le221s00t-k12',
#    'media': [{'path': 'LE/22/1S/00/TK/12/LE221S00T-K12@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1S/00/TK/12/LE221S00T-K12@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU111A0BM-A11',
#    'name': 'CELL STELLAR - Baskets basses - white/black',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '83,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'puma-cell-stellar-baskets-basses-whiteblack-pu111a0bm-a11',
#    'media': [{'path': 'PU/11/1A/0B/MA/11/PU111A0BM-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'AD121A099-Q11',
#    'name': 'Pantalon de survêtement - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '44,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'adidas-originals-adicolor-pantalon-de-survetement-ad121a099-q11',
#    'media': [{'path': 'AD/12/1A/09/9Q/11/AD121A099-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AD/12/1A/09/9Q/11/AD121A099-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU111A094-A13',
#    'name': 'CALI - Baskets basses - white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'puma-cali-baskets-basses-pu111a094-a13',
#    'media': [{'path': 'PU/11/1A/09/4A/13/PU111A094-A13@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'FAA21C06O-K11',
#    'name': "MARKLE - Robe d'été - navy",
#    'price': {'original': '39,99\xa0€',
#     'promotional': '36,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38', '40', '42', '44'],
#    'url_key': 'fashion-union-markle-robe-dete-navy-faa21c06o-k11',
#    'media': [{'path': 'FA/A2/1C/06/OK/11/FAA21C06O-K11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FA/A2/1C/06/OK/11/FAA21C06O-K11@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fashion Union',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NE211A08H-K11',
#    'name': 'WL373 - Baskets basses - navy',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '59,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '41.5',
#     '42.5'],
#    'url_key': 'new-balance-wl373-baskets-basses-ne211a08h-k11',
#    'media': [{'path': 'NE/21/1A/08/HK/11/NE211A08H-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Balance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'PU111A0C6-A11',
#    'name': 'NOVA - Baskets basses - white',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '75,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'puma-nova-baskets-basses-pu111a0c6-a11',
#    'media': [{'path': 'PU/11/1A/0C/6A/11/PU111A0C6-A11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-16%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'LA221D03T-K11',
#    'name': 'ROUND NECK CLASSIC TEE - T-shirt basique - marine',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '40,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38', '40', '42', '44', '46'],
#    'url_key': 'lacoste-classic-tee-t-shirt-basique-la221d03t-k11',
#    'media': [{'path': 'LA/22/1D/03/TK/11/LA221D03T-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/1D/03/TK/11/LA221D03T-K11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'C1821D05P-Q11',
#    'name': 'INSTITUTIONAL LOGO TEE - T-shirt imprimé - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '27,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'calvin-klein-jeans-institutional-slim-fit-tee-t-shirt-imprime-c1821d05p-q11',
#    'media': [{'path': 'C1/82/1D/05/PQ/11/C1821D05P-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'C1/82/1D/05/PQ/11/C1821D05P-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Calvin Klein Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PU115O01A-K11',
#    'name': 'SMASH V2 - Baskets basses - peacoat/white',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '38,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46'],
#    'url_key': 'puma-smash-baskets-basses-pu115o01a-k11',
#    'media': [{'path': 'PU/11/5O/01/AK/11/PU115O01A-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'LE221D033-C11',
#    'name': 'THE PERFECT - T-shirt imprimé - grey',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'levi-s-the-perfect-t-shirt-imprime-le221d033-c11',
#    'media': [{'path': 'LE/22/1D/03/3C/11/LE221D033-C11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1D/03/3C/11/LE221D033-C11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'VA215B000-K11',
#    'name': 'OLD SKOOL - Chaussures de skate - navy',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '67,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-old-skool-baskets-basses-va215b000-k11',
#    'media': [{'path': 'VA/21/5B/00/0K/11/VA215B000-K11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'ZI111NA47-Q11',
#    'name': 'Bottines à talons hauts - black',
#    'price': {'original': '109,99\xa0€',
#     'promotional': '44,00\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41', '42'],
#    'url_key': 'zign-boots-a-talons-black-zi111na47-q11',
#    'media': [{'path': 'ZI/11/1N/A4/7Q/11/ZI111NA47-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Zign',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -60%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe'},
#   {'sku': 'EG234G002-S11',
#    'name': 'EGYPTIAN MAGIC SKIN CREAM 59ML - Soin de jour - -',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False,
#     'base_price': '43,14\xa0€ / 100 ml'},
#    'sizes': [],
#    'url_key': 'egyptian-magic-egyptian-magic-skin-cream-59ml-soin-de-jour-neutral-eg234g002-s11',
#    'media': [{'path': 'EG/23/4G/00/2S/11/EG234G002-S11@2.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Egyptian Magic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'natural', 'value': 'Naturels', 'tracking_value': 'natural'}],
#    'product_group': 'beauty',
#    'amount': '59 ml'},
#   {'sku': 'PU115O05Z-Q11',
#    'name': 'RS-X TECH - Baskets basses - vaporous gray/fair aqua',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '76,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47'],
#    'url_key': 'puma-rs-x-tech-baskets-basses-vaporous-grayfair-aqua-pu115o05z-q11',
#    'media': [{'path': 'PU/11/5O/05/ZQ/11/PU115O05Z-Q11@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'RE011A07I-A11',
#    'name': 'AZTREK DOUBLE POPS - Baskets basses - white/grape punch/bright',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '98,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '35.5',
#     '36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5'],
#    'url_key': 'reebok-classic-aztrek-double-pops-baskets-basses-re011a07i-a11',
#    'media': [{'path': 'RE/01/1A/07/IA/11/RE011A07I-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
# ...
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'campaigns',
#    'label': 'Campagnes',
#    'url_key': 'camp',
#    'kind': 'single_value',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}]}],
#  'total_article_count': 97694,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promotions',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/',
#      'children': [],
#      'article_count': 65071},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/',
#      'children': [],
#      'article_count': 25444},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/',
#      'children': [],
#      'article_count': 6884},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/',
#      'children': [],
#      'article_count': 5254},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/',
#      'children': [],
#      'article_count': 6108},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/',
#      'children': [],
#      'article_count': 5849},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/',
#      'children': [],
#      'article_count': 205}],
#    'article_count': 97694}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/'},
#     {'label': 'Promotions',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Promotions',
#       'seo_label': 'Promotions femme',
#       'reset_url': '/',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/',
#   'reset_url': '/promo-femme/',
#   'app_url': '?urlKey=promo-femme&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Promotions',
#     'seo_label': 'Promotions femme',
#     'reset_url': '/',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'outwardTeaserCard': False,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'sortingInFilter': False,
#   'groupToggleFilters': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'search-dialog': [9, 19],
#   'search-dialog-mobile': [8, 15],
#   'search-dialog-fullwidth': [12, 25],
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': True,
#  'toggleGroupData': None,
#  'seoText': 'Faire du shopping sans culpabiliser ? Avec nos promos pour femme, c’est possible ! Offrez-vous les incontournables de cette saison tels que le bomber XXL ou les loafers à prix réduit. Mais attention, ils partent vite !',
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/5a83c64b-2182-4119-b8f3-81c5f9c74e8a/fd9cb731-1393-476c-b54f-5ea80f9f431b/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=f4c93a27-7d97-4b57-ad33-bbf1d3f570d9&timeUnit=null&timeUnitCount=null&uuid=40d9501d-186b-486e-b25d-b87aa477f2db&bid=null&requestId=2e635fbf-d3c8-4d86-85d1-3c26bb32ac69&s=623984400AE130EA4FF4E399E1E3BD87'],
#    'images': [{'aspect_ratio': '75:64',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/12c217fc-c59b-49d7-a9bb-41355a0dc982.jpg',
#      'image_width': 750},
#     {'aspect_ratio': '16:3',
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/38d319a5-a099-43f4-91c7-c4a9b14cdec7.jpg',
#      'image_width': 3200}],
#    'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9',
#    'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#    'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#    'text_fields': {'cta': "J'en profite",
#     'legal_claim': '*Offre valable du 04/08/2019 au 06/08/2019 jusqu\'à 23h59 sur les articles de la sélection "-20% EXTRA", pour un minimum d\'achat de 70€',
#     'voucher_code': 'SABLE19',
#     'sales_template': 'Voucher',
#     'title': 'Dernière chance !',
#     'type': 'sales',
#     'byline': "SOLDES JUSQU'À -70% ET -20% EXTRA*",
#     'voucher_label': 'Code :'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': '3A94VaBI4K5Z60hb',
#       'price': 0,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': '2e635fbf-d3c8-4d86-85d1-3c26bb32ac69',
#       'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#       'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9',
#      'name': 'Dernière chance !',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '3A94VaBI4K5Z60hb',
#        'price': 0,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '2e635fbf-d3c8-4d86-85d1-3c26bb32ac69',
#        'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#        'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9',
#      'name': 'Dernière chance !',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '3A94VaBI4K5Z60hb',
#        'price': 0,
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '2e635fbf-d3c8-4d86-85d1-3c26bb32ac69',
#        'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#        'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/5a83c64b-2182-4119-b8f3-81c5f9c74e8a/fd9cb731-1393-476c-b54f-5ea80f9f431b/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=f4c93a27-7d97-4b57-ad33-bbf1d3f570d9&timeUnit=null&timeUnitCount=null&uuid=f55094ed-8b41-417e-be4d-92f65895d837&bid=null&requestId=2e635fbf-d3c8-4d86-85d1-3c26bb32ac69&s=BC91FA8385AA0C71353D25425D625B15'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '3A94VaBI4K5Z60hb',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#      'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9',
#      'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'TCT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_CatAd_copy_C_000000',
#      'brand_code': '-1',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': '3A94VaBI4K5Z60hb',
#      'price': 0,
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': '2e635fbf-d3c8-4d86-85d1-3c26bb32ac69',
#      'campaign_id': '5a83c64b-2182-4119-b8f3-81c5f9c74e8a',
#      'creative_id': 'f4c93a27-7d97-4b57-ad33-bbf1d3f570d9'}},
#    'click_url': 'https://www.zalando.fr/femme/?camp=fr_ss19_eoss_wave_4_countdown_2019_28'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/5058eecf-7e01-4515-b3fe-3e6f6f00fdf0/fd9cb731-1393-476c-b54f-5ea80f9f431b/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2935812f-d196-4935-a7e2-2c5cbd621a72&timeUnit=null&timeUnitCount=null&uuid=13ebee3c-9997-4e32-8117-4790ea8a5db9&bid=null&requestId=c5735877-cf7b-4f51-8643-18db20be604b&s=778E240C87A91079CFD3EED8BC8358C5'],
#    'images': [{'aspect_ratio': '132:199',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/0ae44139-e4d1-4d08-9083-156d3dea1cdd.jpg',
#      'image_width': 792}],
#    'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72',
#    'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#    'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#    'text_fields': {'cta': "JUSQU'À -70% ET -20% EXTRA*", 'title': 'SOLDES'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'catalog',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#       'brand_code': '-1',
#       'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#       'flow_id': '3A94VaBI4K5Z60hb',
#       'price': 0,
#       'shop_slot_id': 'in_catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': 'c5735877-cf7b-4f51-8643-18db20be604b',
#       'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#       'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72'}},
#     'view': {'type': 'teaser view',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2935812f-d196-4935-a7e2-2c5cbd621a72',
#      'name': 'SOLDES',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': '3A94VaBI4K5Z60hb',
#        'price': 0,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'c5735877-cf7b-4f51-8643-18db20be604b',
#        'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#        'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72'}}},
#     'click': {'type': 'teaser click',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '2935812f-d196-4935-a7e2-2c5cbd621a72',
#      'name': 'SOLDES',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': '3A94VaBI4K5Z60hb',
#        'price': 0,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': 'c5735877-cf7b-4f51-8643-18db20be604b',
#        'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#        'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/5058eecf-7e01-4515-b3fe-3e6f6f00fdf0/fd9cb731-1393-476c-b54f-5ea80f9f431b/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=2935812f-d196-4935-a7e2-2c5cbd621a72&timeUnit=null&timeUnitCount=null&uuid=12764dc9-8e0d-4430-853c-bc851fa23660&bid=null&requestId=c5735877-cf7b-4f51-8643-18db20be604b&s=0C77B9513FF75BE80FF793143E32F8F1'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '3A94VaBI4K5Z60hb',
#      'entity_id': None,
#      'shop_slot_id': 'in_catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#      'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72',
#      'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'IN CAT FR SS19 EOSS Wave 4 FS Countdown Women_FR_FR_WOMAN_August_4_6_InCatAd_copy_C_000000',
#      'brand_code': '-1',
#      'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#      'flow_id': '3A94VaBI4K5Z60hb',
#      'price': 0,
#      'shop_slot_id': 'in_catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': 'c5735877-cf7b-4f51-8643-18db20be604b',
#      'campaign_id': '5058eecf-7e01-4515-b3fe-3e6f6f00fdf0',
#      'creative_id': '2935812f-d196-4935-a7e2-2c5cbd621a72'}},
#    'click_url': 'https://www.zalando.fr/femme/?camp=fr_ss19_eoss_wave_4_countdown_2019_28'},
#   'channel_name': 'CF',
#   'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951'},
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'styleYourKicks': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#                    brand_name family_articles  \
# 0                        ONLY              []
# 1                        Zign              []
# 2                     Levi's®              []
# 3                        Vila              []
# 4                         OVS              []
# 5          Calvin Klein Jeans              []
# 6              Skechers Sport              []
# 7                 New Balance              []
# 8                    Even&Odd              []
# 9              Reebok Classic              []
# 10                Tommy Jeans              []
# 11                  Noisy May              []
# 12     Champion Reverse Weave              []
# 13                       Vans              []
# 14                  Vero Moda              []
# 15                       Puma              []
# 16                       ONLY              []
# 17           adidas Originals              []
# 18                    K-SWISS              []
# 19                       Vans              []
# 20                    Levi's®              []
# 21         Calvin Klein Jeans              []
# 22                    New Era              []
# 23                    Lacoste              []
# 24           Nike Performance              []
# 25            Nike Sportswear              []
# 26             Victoria Shoes              []
# 27                   Even&Odd              []
# 28                       Puma              []
# 29              Hollister Co.              []
# ..                        ...             ...
# 54                  Vero Moda              []
# 55           adidas Originals              []
# 56                  Noisy May              []
# 57                   Even&Odd              []
# 58                  Vero Moda              []
# 59             Selected Femme              []
# 60                       Puma              []
# 61                        JDY              []
# 62         Calvin Klein Jeans              []
# 63                    Levi's®              []
# 64                   Converse              []
# 65           adidas Originals              []
# 66                       ONLY              []
# 67  Dorothy Perkins Maternity              []
# 68                    Diadora              []
# 69                  Vero Moda              []
# 70                    TWINTIP              []
# 71                   Converse              []
# 72                   Even&Odd              []
# 73                    Levi's®              []
# 74          Melvin & Hamilton              []
# 75             Reebok Classic              []
# 76                      Guess              []
# 77                       Vila              []
# 78            Nike Sportswear              []
# 79                    Levi's®              []
# 80                    Lacoste              []
# 81                       Vila              []
# 82                     Object              []
# 83         Calvin Klein Jeans              []
#
#                                                 flags  is_premium  \
# 0   [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 2   [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 3   [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 4   [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 5   [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 6   [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 7   [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 8   [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 9   [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# 10  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 11  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 12  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 13  [{'key': 'discountRate', 'value': 'Jusqu’à -20...       False
# 14  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 15  [{'key': 'discountRate', 'value': 'Jusqu’à -10...       False
# 16  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# 17  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...       False
# 18  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 19  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 20  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# 21  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 22  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 23  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# 24  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 25  [{'key': 'discountRate', 'value': 'Jusqu’à -26...       False
# 26  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 27  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 28  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 29  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# ..                                                ...         ...
# 54  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 55  [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# 56  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 57  [{'key': 'discountRate', 'value': '-35%', 'tra...       False
# 58  [{'key': 'discountRate', 'value': 'Jusqu’à -45...       False
# 59  [{'key': 'discountRate', 'value': 'Jusqu’à -45...       False
# 60  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 61  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# 62  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 63  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 64  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# 65  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# 66  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# 67  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 68  [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# 69  [{'key': 'discountRate', 'value': '-35%', 'tra...       False
# 70  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 71  [{'key': 'discountRate', 'value': 'Jusqu’à -10...       False
# 72  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 73  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 74  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 75  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 76  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# 77  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# 78  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 79  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# 81  [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# 82  [{'key': 'discountRate', 'value': 'Jusqu’à -40...       False
# 83  [{'key': 'discountRate', 'value': '-10%', 'tra...       False
#
#                                                 media  \
# 0   [{'path': 'ON/32/1E/1C/LA/12/ON321E1CL-A12@8.j...
# 1   [{'path': 'ZI/11/1A/0G/4Q/11/ZI111A0G4-Q11@3.j...
# 2   [{'path': 'LE/22/1D/05/1A/11/LE221D051-A11@17....
# 3   [{'path': 'V1/02/1E/0V/JK/11/V1021E0VJ-K11@21....
# 4   [{'path': 'OV/02/1E/02/DA/11/OV021E02D-A11@7.j...
# 5   [{'path': 'C1/82/1D/06/WA/11/C1821D06W-A11@8.j...
# 6   [{'path': 'SK/21/1A/05/HA/11/SK211A05H-A11@11....
# 7   [{'path': 'NE/21/1A/08/JJ/11/NE211A08J-J11@6.j...
# 8   [{'path': 'EV/42/1T/03/OE/11/EV421T03O-E11@11....
# 9   [{'path': 'RE/01/1S/03/HQ/12/RE011S03H-Q12@13....
# 10  [{'path': 'TO/B2/1E/00/EA/11/TOB21E00E-A11@6.j...
# 11  [{'path': 'NM/32/1C/0A/1Q/11/NM321C0A1-Q11@4.j...
# 12  [{'path': 'C0/T2/1D/00/PQ/11/C0T21D00P-Q11@8.j...
# 13  [{'path': 'VA/21/5N/00/5Q/11/VA215N005-Q11@12....
# 14  [{'path': 'VE/12/1C/1P/XK/11/VE121C1PX-K11@14....
# 15  [{'path': 'PU/11/5O/02/4Q/13/PU115O024-Q13@10....
# 16  [{'path': 'ON/32/1S/06/MO/11/ON321S06M-O11@7.j...
# 17  [{'path': 'AD/11/1A/0T/BA/11/AD111A0TB-A11@9.j...
# 18  [{'path': 'KS/11/1S/01/0A/11/KS111S010-A11@14....
# 19  [{'path': 'VA/21/5O/01/OQ/11/VA215O01O-Q11@5.j...
# 20  [{'path': 'LE/22/1J/00/UC/11/LE221J00U-C11@10....
# 21  [{'path': 'C1/82/1D/05/PA/11/C1821D05P-A11@8.j...
# 22  [{'path': 'NE/35/1B/04/4A/11/NE351B044-A11@11....
# 23  [{'path': 'LA/22/1D/03/AJ/11/LA221D03A-J11@8.j...
# 24  [{'path': 'N1/24/1A/0N/OQ/11/N1241A0NO-Q11@9.1...
# 25  [{'path': 'NI/12/1A/05/EQ/11/NI121A05E-Q11@1.1...
# 26  [{'path': 'VI/21/1S/01/9F/11/VI211S019-F11@12....
# 27  [{'path': 'EV/42/1C/0T/2Q/11/EV421C0T2-Q11@20....
# 28  [{'path': 'PU/11/5O/03/7Q/12/PU115O037-Q12@2.j...
# 29  [{'path': 'H0/42/1D/04/1A/11/H0421D041-A11@9.2...
# ..                                                ...
# 54  [{'path': 'VE/12/1U/06/QO/11/VE121U06Q-O11@8.j...
# 55  [{'path': 'AD/11/1A/0O/OA/11/AD111A0OO-A11@13....
# 56  [{'path': 'NM/32/1S/01/KK/11/NM321S01K-K11@10....
# 57  [{'path': 'EV/45/1M/00/YD/11/EV451M00Y-D11@6.j...
# 58  [{'path': 'VE/12/1U/00/2I/11/VE121U002-I11@4.j...
# 59  [{'path': 'SE/52/1I/0F/QK/11/SE521I0FQ-K11@10....
# 60  [{'path': 'PU/11/1A/0B/OQ/11/PU111A0BO-Q11@12....
# 61  [{'path': 'JY/12/1N/02/OC/11/JY121N02O-C11@8.j...
# 62  [{'path': 'C1/82/1D/05/PC/11/C1821D05P-C11@8.j...
# 63  [{'path': 'LE/22/1D/03/UQ/11/LE221D03U-Q11@8.j...
# 64  [{'path': 'CO/41/5A/08/G5/03/CO415A08G-503@9.j...
# 65  [{'path': 'AD/11/5O/01/6Q/11/AD115O016-Q11@12....
# 66  [{'path': 'ON/32/1E/10/DK/11/ON321E10D-K11@10....
# 67  [{'path': 'DP/82/9F/05/FG/11/DP829F05F-G11@12....
# 68  [{'path': 'D2/91/2B/00/FK/11/D2912B00F-K11@2.j...
# 69  [{'path': 'VE/12/1I/11/ZC/11/VE121I11Z-C11@4.j...
# 70  [{'path': 'TW/42/1C/05/RK/11/TW421C05R-K11@17....
# 71  [{'path': 'CO/41/5A/00/H9/09/CO415A00H-909@19....
# 72  [{'path': 'EV/42/1C/0T/GQ/11/EV421C0TG-Q11@20....
# 73  [{'path': 'LE/22/1N/05/BK/14/LE221N05B-K14@8.j...
# 74  [{'path': 'ME/21/1E/01/MQ/11/ME211E01M-Q11@3.j...
# 75  [{'path': 'RE/51/1A/01/88/02/RE511A018-802@20....
# 76  [{'path': 'GU/11/1A/0G/NQ/11/GU111A0GN-Q11@10....
# 77  [{'path': 'V1/02/1D/0K/FA/11/V1021D0KF-A11@14....
# 78  [{'path': 'NI/12/1J/0B/8C/11/NI121J0B8-C11@4.j...
# 79  [{'path': 'LE/22/1D/05/GA/12/LE221D05G-A12@10....
# 80  [{'path': 'LA/22/1D/03/AK/11/LA221D03A-K11@16....
# 81  [{'path': 'V1/02/1I/0F/OA/11/V1021I0FO-A11@9.j...
# 82  [{'path': 'OB/12/1U/01/IQ/11/OB121U01I-Q11@16....
# 83  [{'path': 'C1/82/1D/06/WC/11/C1821D06W-C11@8.j...
#
#                                                  name  \
# 0             ONLSUGAR FALLOW - Blouse - cloud dancer
# 1                                  Ballerines - black
# 2               PERFECT TEE - T-shirt basique - black
# 3   VISUMI NEW BACK - T-shirt imprimé - total eclipse
# 4                                   Chemisier - white
# 5   CORE MONOGRAM LOGO - T-shirt imprimé - bright ...
# 6                SIDE STREET - Baskets basses - white
# 7                  WL574 - Baskets basses - pink/blue
# 8                               Combinaison - mustard
# 9                    CLASSIC - Baskets basses - black
# 10               ORIGINAL - Chemisier - classic white
# 11        NMMAYDEN 2/4 DRESS - Robe en jersey - black
# 12                 CREWNECK - T-shirt imprimé - black
# 13  UA SK8-MID REISSUE - Baskets montantes - black...
# 14  VMSASHA BALI DRESS - Robe d'été - navy blazer/...
# 15                     SMASH - Baskets basses - black
# 16        ONLTURNER PAPER BAG  - Short - russet brown
# 17  SLEEK MID - Baskets montantes - footwear white...
# 18  CLEAN COURT CMF - Baskets basses - white/gull ...
# 19    UA DIAMO NI - Baskets basses - black/true white
# 20  GRAPHIC SPORT - Sweat à capuche - smokestack h...
# 21  INSTITUTIONAL LOGO TEE - T-shirt imprimé - bri...
# 22               LEAGUE ESSENTIAL - Casquette - white
# 23                           PF7845 - Polo - flamingo
# 24  REVOLUTION 4 - Chaussures de running neutres -...
# 25      GYM VINTAGE - Pantalon de survêtement - black
# 26   DEPORTIVO BASKET GLITTER - Baskets basses - rosa
# 27                             Robe de soirée - black
# 28              AXIS - Baskets basses - black/asphalt
# 29                   SHORT SLEEVE CORE - Polo - white
# ..                                                ...
# 54                  VMEVA ABBY - Trench - silver mink
# 55  CONTINENTAL 80 - Baskets basses - footwear whi...
# 56  NMBE LUCY FOLD - Short en jean - light blue denim
# 57                           Montre - silver-coloured
# 58    VMROYCE SHORT JACKET - Veste en cuir - old rose
# 59                SLFMINNA O NECK - Pullover - skyway
# 60   CALI BOLD - Baskets basses - black/metallic gold
# 61                          Jeans Skinny - grey denim
# 62  INSTITUTIONAL LOGO TEE - T-shirt imprimé - lig...
# 63              THE PERFECT - T-shirt imprimé - black
# 64   CHUCK TAYLOR ALL STAR OX - Baskets basses - navy
# 65              GAZELLE - Baskets basses - core black
# 66                  ONLVIC SOLID - Blouse - night sky
# 67                     WRAP DRESS - Robe longue - red
# 68                Baskets basses - insignia blue/gray
# 69   VMNORA  BOATNECK - Pullover - light grey melange
# 70                      Robe en jean - mid blue denim
# 71  CHUCK TAYLOR ALL STAR HI - Baskets montantes -...
# 72                              Robe fourreau - black
# 73                     RIBCAGE - Jean droit - georgie
# 74                      SCARLETT  - Mocassins - black
# 75              FREESTYLE - Baskets montantes - black
# 76                   BRANDIA - Baskets basses - black
# 77    VINOEL V NECK  - T-shirt basique - cloud dancer
# 78  HOODIE - veste en sweat zippée - grey heather/...
# 79      THE PERFECT TEE - T-shirt imprimé - white/red
# 80                          PF7845 - Polo - navy blue
# 81                  VIPLACE - Gilet - natural melange
# 82      OBJBEAU LONG COAT - Manteau classique - black
# 83  CORE MONOGRAM LOGO - T-shirt imprimé - light g...
#
#                                               outfits  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72  [{'id': 'ButV6-NISOa', 'url_key': '/outfits/Bu...
# 73  [{'id': 'fzKibCVKTda', 'url_key': '/outfits/fz...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#     price.has_different_original_prices  price.has_different_prices  \
# 0                                 False                       False
# 1                                 False                       False
# 2                                 False                       False
# 3                                 False                       False
# 4                                 False                       False
# 5                                 False                       False
# 6                                 False                       False
# 7                                 False                       False
# 8                                 False                       False
# 9                                 False                        True
# 10                                False                       False
# 11                                False                       False
# 12                                False                       False
# 13                                False                        True
# 14                                False                       False
# 15                                False                        True
# 16                                False                       False
# 17                                False                       False
# 18                                False                       False
# 19                                False                       False
# 20                                False                       False
# 21                                False                       False
# 22                                False                       False
# 23                                False                       False
# 24                                False                       False
# 25                                False                        True
# 26                                False                       False
# 27                                False                       False
# 28                                False                       False
# 29                                False                       False
# ..                                  ...                         ...
# 54                                False                       False
# 55                                False                        True
# 56                                False                       False
# 57                                False                       False
# 58                                False                        True
# 59                                False                        True
# 60                                False                       False
# 61                                False                       False
# 62                                False                       False
# 63                                False                       False
# 64                                False                       False
# 65                                False                       False
# 66                                False                       False
# 67                                False                       False
# 68                                False                       False
# 69                                False                       False
# 70                                False                       False
# 71                                False                        True
# 72                                False                       False
# 73                                False                       False
# 74                                False                       False
# 75                                False                       False
# 76                                False                       False
# 77                                False                       False
# 78                                False                       False
# 79                                False                       False
# 80                                False                        True
# 81                                False                        True
# 82                                False                        True
# 83                                False                       False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
# 8                                    False
# 9                                     True
# 10                                   False
# 11                                   False
# 12                                   False
# 13                                    True
# 14                                   False
# 15                                    True
# 16                                   False
# 17                                   False
# 18                                   False
# 19                                   False
# 20                                   False
# 21                                   False
# 22                                   False
# 23                                   False
# 24                                   False
# 25                                    True
# 26                                   False
# 27                                   False
# 28                                   False
# 29                                   False
# ..                                     ...
# 54                                   False
# 55                                    True
# 56                                   False
# 57                                   False
# 58                                    True
# 59                                    True
# 60                                   False
# 61                                   False
# 62                                   False
# 63                                   False
# 64                                   False
# 65                                   False
# 66                                   False
# 67                                   False
# 68                                   False
# 69                                   False
# 70                                   False
# 71                                    True
# 72                                   False
# 73                                   False
# 74                                   False
# 75                                   False
# 76                                   False
# 77                                   False
# 78                                   False
# 79                                   False
# 80                                    True
# 81                                    True
# 82                                    True
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only price.original  \
# 0                                       False        26,99 €
# 1                                       False        89,95 €
# 2                                       False        19,95 €
# 3                                       False        21,99 €
# 4                                       False        34,95 €
# 5                                       False        39,95 €
# 6                                       False        79,95 €
# 7                                       False        89,95 €
# 8                                       False        34,95 €
# 9                                       False        89,95 €
# 10                                      False        69,95 €
# 11                                      False        16,99 €
# 12                                      False        44,95 €
# 13                                      False        79,95 €
# 14                                      False        26,95 €
# 15                                      False        54,95 €
# 16                                      False        19,99 €
# 17                                      False        99,95 €
# 18                                      False        69,95 €
# 19                                      False        79,95 €
# 20                                      False        64,95 €
# 21                                      False        29,95 €
# 22                                      False        19,95 €
# 23                                      False        94,95 €
# 24                                      False        49,95 €
# 25                                      False        44,95 €
# 26                                      False        69,95 €
# 27                                      False        34,95 €
# 28                                      False        54,95 €
# 29                                      False        24,95 €
# ..                                        ...            ...
# 54                                      False        39,99 €
# 55                                      False        99,95 €
# 56                                      False        19,99 €
# 57                                      False        16,99 €
# 58                                      False        99,99 €
# 59                                      False        49,99 €
# 60                                      False        89,95 €
# 61                                      False        24,99 €
# 62                                      False        29,95 €
# 63                                      False        19,95 €
# 64                                      False        64,95 €
# 65                                      False        99,95 €
# 66                                      False        19,99 €
# 67                                      False        49,95 €
# 68                                      False        79,95 €
# 69                                      False        29,99 €
# 70                                      False        29,95 €
# 71                                      False        69,95 €
# 72                                      False        22,95 €
# 73                                      False       114,95 €
# 74                                      False       169,95 €
# 75                                      False        89,95 €
# 76                                      False       119,95 €
# 77                                      False        16,99 €
# 78                                      False        54,95 €
# 79                                      False        18,95 €
# 80                                      False        89,95 €
# 81                                      False        54,95 €
# 82                                      False        69,99 €
# 83                                      False        39,95 €
#
#    price.promotional product_group  \
# 0            18,90 €      clothing
# 1            72,00 €          shoe
# 2            18,00 €      clothing
# 3            15,40 €      clothing
# 4            24,44 €      clothing
# 5            36,00 €      clothing
# 6            55,95 €          shoe
# 7            71,95 €          shoe
# 8            28,00 €      clothing
# 9            62,95 €          shoe
# 10           48,95 €      clothing
# 11           15,30 €      clothing
# 12           31,45 €      clothing
# 13           64,00 €          shoe
# 14           21,60 €      clothing
# 15           49,45 €          shoe
# 16           17,00 €      clothing
# 17           84,95 €          shoe
# 18           48,95 €          shoe
# 19           55,95 €          shoe
# 20           48,45 €      clothing
# 21           27,00 €      clothing
# 22           16,00 €   accessoires
# 23           70,95 €      clothing
# 24           39,95 €          shoe
# 25           33,45 €      clothing
# 26           48,95 €          shoe
# 27           28,00 €      clothing
# 28           38,45 €          shoe
# 29           20,00 €      clothing
# ..               ...           ...
# 54           28,00 €      clothing
# 55           69,95 €          shoe
# 56           14,00 €      clothing
# 57           11,05 €   accessoires
# 58           54,95 €      clothing
# 59           27,45 €      clothing
# 60           80,95 €          shoe
# 61           18,75 €      clothing
# 62           27,00 €      clothing
# 63           18,00 €      clothing
# 64           55,00 €          shoe
# 65           74,95 €          shoe
# 66           15,00 €      clothing
# 67           34,95 €      clothing
# 68           40,00 €          shoe
# 69           19,50 €      clothing
# 70           21,00 €      clothing
# 71           63,00 €          shoe
# 72           18,36 €      clothing
# 73          103,00 €      clothing
# 74          118,95 €          shoe
# 75           71,95 €          shoe
# 76          101,95 €          shoe
# 77           14,45 €      clothing
# 78           49,46 €      clothing
# 79           17,00 €      clothing
# 80           62,95 €      clothing
# 81           38,45 €      clothing
# 82           42,00 €      clothing
# 83           36,00 €      clothing
#
#                                                 sizes            sku  \
# 0                                [36, 38, 40, 42, 44]  ON321E1CL-A12
# 1                                [36, 38, 40, 41, 42]  ZI111A0G4-Q11
# 2                              [XXS, XS, S, M, L, XL]  LE221D051-A11
# 3                                [36, 38, 40, 42, 44]  V1021E0VJ-K11
# 4                                           [S, M, L]  OV021E02D-A11
# 5                                   [XS, S, M, L, XL]  C1821D06W-A11
# 6                        [35, 36, 37, 38, 39, 40, 41]  SK211A05H-A11
# 7    [36, 36.5, 37, 37.5, 38, 39, 40, 41, 41.5, 42.5]  NE211A08J-J11
# 8                                    [36, 38, 40, 42]  EV421T03O-E11
# 9   [35, 35.5, 36, 37, 37.5, 38, 38.5, 39, 40, 40....  RE011S03H-Q12
# 10                                  [XS, S, M, L, XL]  TOB21E00E-A11
# 11                               [36, 38, 40, 42, 44]  NM321C0A1-Q11
# 12                                  [XS, S, M, L, XL]  C0T21D00P-Q11
# 13  [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....  VA215N005-Q11
# 14                                  [XS, S, M, L, XL]  VE121C1PX-K11
# 15  [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42,...  PU115O024-Q13
# 16                                   [36, 38, 40, 42]  ON321S06M-O11
# 17  [36, 38, 40, 42, 36 2/3, 37 1/3, 38 2/3, 39 1/...  AD111A0TB-A11
# 18                       [36, 37, 38, 39, 40, 41, 42]  KS111S010-A11
# 19  [34.5, 35, 36.5, 38, 39, 40, 40.5, 41, 42, 42....  VA215O01O-Q11
# 20                             [XXS, XS, S, M, L, XL]  LE221J00U-C11
# 21                                  [XS, S, M, L, XL]  C1821D05P-A11
# 22                                         [One Size]  NE351B044-A11
# 23                   [32, 34, 36, 40, 42, 44, 46, 48]  LA221D03A-J11
# 24  [36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 4...  N1241A0NO-Q11
# 25                                  [XS, S, M, L, XL]  NI121A05E-Q11
# 26                           [35, 36, 37, 38, 39, 40]  VI211S019-F11
# 27                                   [36, 38, 40, 42]  EV421C0T2-Q11
# 28  [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42,...  PU115O037-Q12
# 29                                      [XS, S, M, L]  H0421D041-A11
# ..                                                ...            ...
# 54                                  [XS, S, M, L, XL]  VE121U06Q-O11
# 55  [36, 38, 40, 42, 44, 36 2/3, 37 1/3, 38 2/3, 3...  AD111A0OO-A11
# 56                               [36, 38, 40, 42, 44]  NM321S01K-K11
# 57                                         [One Size]  EV451M00Y-D11
# 58                                  [XS, S, M, L, XL]  VE121U002-I11
# 59                               [36, 38, 40, 42, 44]  SE521I0FQ-K11
# 60     [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42]  PU111A0BO-Q11
# 61  [Lx30, Lx32, Lx34, Mx30, Mx32, Mx34, Sx30, Sx3...  JY121N02O-C11
# 62                                  [XS, S, M, L, XL]  C1821D05P-C11
# 63                             [XXS, XS, S, M, L, XL]  LE221D03U-Q11
# 64  [36.5, 37, 37.5, 38, 39, 39.5, 40, 41, 41.5, 4...  CO415A08G-503
# 65  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...  AD115O016-Q11
# 66                                   [36, 38, 40, 42]  ON321E10D-K11
# 67                   [34, 36, 38, 40, 42, 44, 46, 48]  DP829F05F-G11
# 68  [36, 36.5, 38.5, 39, 40, 40.5, 41, 42, 42.5, 4...  D2912B00F-K11
# 69                                      [XS, S, M, L]  VE121I11Z-C11
# 70                               [36, 38, 40, 42, 44]  TW421C05R-K11
# 71  [35, 37, 37.5, 38, 39, 39.5, 40, 41, 41.5, 42,...  CO415A00H-909
# 72                               [36, 38, 40, 42, 44]  EV421C0TG-Q11
# 73  [23x27, 24x27, 24x29, 25x27, 26x27, 26x29, 27x...  LE221N05B-K14
# 74               [35, 36, 37, 38, 39, 40, 41, 42, 43]  ME211E01M-Q11
# 75  [35, 35.5, 36, 37, 37.5, 38, 38.5, 39, 40, 40....  RE511A018-802
# 76                       [35, 36, 37, 38, 39, 40, 41]  GU111A0GN-Q11
# 77                                  [XS, S, M, L, XL]  V1021D0KF-A11
# 78                                  [XS, S, M, L, XL]  NI121J0B8-C11
# 79                             [XXS, XS, S, M, L, XL]  LE221D05G-A12
# 80               [32, 34, 36, 38, 40, 42, 44, 46, 48]  LA221D03A-K11
# 81                                      [XS, S, M, L]  V1021I0FO-A11
# 82                                  [XS, S, M, L, XL]  OB121U01I-Q11
# 83                                  [XS, S, M, L, XL]  C1821D06W-C11
#
#                                               url_key
# 0           only-onlsugar-fallow-blouse-on321e1cl-a12
# 1                 zign-ballerines-black-zi111a0g4-q11
# 2    levisr-perfect-tee-t-shirt-imprime-le221d051-a11
# 3   vila-visumi-new-back-t-shirt-imprime-total-ecl...
# 4                   ovs-chemisier-white-ov021e02d-a11
# 5   calvin-klein-jeans-core-monogram-logo-regular-...
# 6   skechers-sport-side-street-baskets-basses-whit...
# 7   new-balance-wl574-baskets-basses-pinkblue-ne21...
# 8        evenandodd-combinaison-mustard-ev421t03o-e11
# 9   reebok-classic-classic-baskets-basses-re011s03...
# 10       tommy-jeans-original-chemisier-tob21e00e-a11
# 11  noisy-may-nmmayden-24-dress-robe-en-jersey-nm3...
# 12  champion-reverse-weave-crewneck-t-shirt-imprim...
# 13  vans-ua-sk8-mid-reissue-baskets-montantes-va21...
# 14  vero-moda-vmsasha-bali-short-dress-robe-dete-v...
# 15            puma-smash-baskets-basses-pu115o024-q13
# 16              only-short-russet-brown-on321s06m-o11
# 17  adidas-originals-sleek-mid-baskets-montantes-f...
# 18  k-swiss-baskets-basses-whitegull-gray-ks111s01...
# 19         vans-diamo-ni-baskets-basses-va215o01o-q11
# 20  levisr-graphic-sport-sweatshirt-smokestack-hea...
# 21  calvin-klein-jeans-institutional-slim-fit-tee-...
# 22  new-era-league-essential-casquette-white-ne351...
# 23                lacoste-polo-flamingo-la221d03a-j11
# 24  nike-performance-revolution-4-eu-chaussures-de...
# 25  nike-sportswear-gym-vintage-pantalon-de-survet...
# 26   victoria-shoes-baskets-basses-rosa-vi211s019-f11
# 27      evenandodd-robe-de-soiree-black-ev421c0t2-q11
# 28             puma-axis-baskets-basses-pu115o037-q12
# 29  hollister-co-short-sleeve-core-t-shirt-imprime...
# ..                                                ...
# 54          vero-moda-vmeva-abby-trench-ve121u06q-o11
# 55  adidas-originals-continental-80-baskets-basses...
# 56  noisy-may-nmbe-lucy-fold-short-en-jean-light-b...
# 57    evenandodd-montre-silver-coloured-ev451m00y-d11
# 58  vero-moda-vmroyce-short-jacket-veste-en-cuir-v...
# 59  selected-femme-slfminna-o-neck-pullover-se521i...
# 60        puma-cali-bold-baskets-basses-pu111a0bo-q11
# 61          jdy-jeans-skinny-grey-denim-jy121n02o-c11
# 62  calvin-klein-jeans-institutional-slim-fit-tee-...
# 63   levisr-the-perfect-t-shirt-imprime-le221d03u-q11
# 64  converse-all-star-ox-baskets-basses-navy-co415...
# 65  adidas-originals-gazelle-baskets-basses-core-b...
# 66  only-onlvic-34-solid-blouse-night-sky-on321e10...
# 67  dorothy-perkins-maternity-wrap-dress-robe-long...
# 68          diadora-baskets-basses-bleu-d2912b00f-k11
# 69  vero-moda-vmnora-34-boatneck-pullover-ve121i11...
# 70  twintip-robe-en-jean-mid-blue-denim-tw421c05r-k11
# 71   converse-ctas-mono-hi-baskets-noir-co415a00h-909
# 72      evenandodd-robe-en-jersey-black-ev421c0tg-q11
# 73        levisr-ribcage-jean-boyfriend-le221n05b-k14
# 74  melvin-and-hamilton-scarlett-mocassins-me211e0...
# 75  reebok-classic-freestyle-hi-baskets-montantes-...
# 76           guess-baskets-basses-black-gu111a0gn-q11
# 77   vila-vinoel-v-neck-t-shirt-basique-v1021d0kf-a11
# 78  nike-sportswear-hoodie-veste-en-sweat-zippee-n...
# 79  levisr-the-perfect-tee-t-shirt-imprime-le221d0...
# 80                  lacoste-pf7845-polo-la221d03a-k11
# 81                   vila-viplace-gilet-v1021i0fo-a11
# 82  object-objbeau-long-coat-veste-dhiver-black-ob...
# 83  calvin-klein-jeans-core-monogram-logo-regular-...
#
# [84 rows x 17 columns]

# %%
flattened_data1.columns

# %%
#4. Find out the total page count in the 1st page data.
# Get the total number of pages

total_pages=results['pagination']['page_count']
print("The total page count contained in the 1st page data is", total_pages)
# Out:
# The total page count contained in the 1st page data is 892

# %%
#5.Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers=headers, timeout=5)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    df = df.append(flattened_data1)

df.head(5)

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
#The trending brand
df.brand_name.value_counts().index[0]
# Out:
# 'Even&Odd'

# %%
#The product(s) with the highest discount

# %%
#The sum of discounts of all goods
