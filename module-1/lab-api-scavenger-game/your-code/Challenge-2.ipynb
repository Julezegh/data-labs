# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#Count how many commits were made in the past week.

#1.Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#2.Count how many commit objects are contained in the array.

# %%
url='https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'
user='Julezegh'
token = 'de4b0a848683fa64789c1838c471ad8537af541d'
response = requests.get(url, auth=(user, token))
forks = response.json()
forks
# Out:
# [{'id': 200138127,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=',
#   'name': 'mad-oct-2018',
#   'full_name': 'gggfaria/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'gggfaria',
#    'id': 13389357,
#    'node_id': 'MDQ6VXNlcjEzMzg5MzU3',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/13389357?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gggfaria',
#    'html_url': 'https://github.com/gggfaria',
#    'followers_url': 'https://api.github.com/users/gggfaria/followers',
#    'following_url': 'https://api.github.com/users/gggfaria/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gggfaria/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gggfaria/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gggfaria/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gggfaria/orgs',
#    'repos_url': 'https://api.github.com/users/gggfaria/repos',
# ...

# %%
flattened_forks = json_normalize(forks)
flattened_forks.head(5)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/gggfaria/mad-oct-...     False
# 1  https://api.github.com/repos/nancyulric/mad-oc...     False
# 2  https://api.github.com/repos/lmartinezruizit/d...     False
# 3  https://api.github.com/repos/eye8/madrid-oct-2...     False
# 4  https://api.github.com/repos/ArieHassan/madrid...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/gggfaria/mad-oct-...
# 1  https://api.github.com/repos/nancyulric/mad-oc...
# 2  https://api.github.com/repos/lmartinezruizit/d...
# 3  https://api.github.com/repos/eye8/madrid-oct-2...
# 4  https://api.github.com/repos/ArieHassan/madrid...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/gggfaria/mad-oct-...
# 1  https://api.github.com/repos/nancyulric/mad-oc...
# 2  https://api.github.com/repos/lmartinezruizit/d...
# ...

# %%
#Create a list of the commits urls
commits= list(flattened_data2['commits_url'])
commits = list(map(lambda x: x[:-6], commits))
print(commits)
# Out:
# ['https://api.github.com/repos/gggfaria/mad-oct-2018/commits', 'https://api.github.com/repos/nancyulric/mad-oct-2018/commits', 'https://api.github.com/repos/lmartinezruizit/datamad0119/commits', 'https://api.github.com/repos/eye8/madrid-oct-2018/commits', 'https://api.github.com/repos/ArieHassan/madrid-oct-2018/commits', 'https://api.github.com/repos/cmvalma/madrid-oct-2018/commits', 'https://api.github.com/repos/criraca/madrid-oct-2018/commits', 'https://api.github.com/repos/boyander/madrid-oct-2018/commits', 'https://api.github.com/repos/AlbertoCastellanos/madrid-oct-2018/commits', 'https://api.github.com/repos/elenajpp/madrid-oct-2018/commits', 'https://api.github.com/repos/pablobarrio/madrid-oct-2018/commits', 'https://api.github.com/repos/miriammg/madrid-oct-2018/commits', 'https://api.github.com/repos/albertogcmr/madrid-oct-2018/commits', 'https://api.github.com/repos/marisfont/madrid-oct-2018/commits']

# %%
commits_url = pd.DataFrame()
for url in commits:
    user='Julezegh'
    token = 'de4b0a848683fa64789c1838c471ad8537af541d'
    response = requests.get(url, auth=(user, token))
    commits_url = commits_url.append(json_normalize(response.json()).set_index('sha'))
print(commits_url)
# Out:
#                                           author  \
# sha
# f332b5e6fcea965dc80f62220d7ee1457b04b90d     NaN
# 4c048c3efc18cf9d50e34c76919c8049ee7f2dbd     NaN
# 41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310     NaN
# 750eb91e4535c14ec4bf03f60cb5756a1c93f68f     NaN
# 4a8cc3cb64821cb58182a3a94be38f17d27a8e8f     NaN
# 1501bac01f8183d223a47ca7f23649a5d98d7e00     NaN
# 6c2a1247d4e13a37261081279f250ffa82ed5c96     NaN
# cc02db3df76c8a16ecee3f7a937366ff427a7c3a     NaN
# 49ba929952728ab17635591cf55137c8af01babb     NaN
# ba93368ee5593b15c7b1829f82cbacb9a003476c     NaN
# 2034c389cb81f30d30f94acc2a5237377d387dc1     NaN
# 09cf3f0163fe3895128cb322f5450672435ede7e     NaN
# 825dea0b3aab60bf587130441fab30d8abab775c     NaN
# ced5e055e9313f60c57a7daab4ee89eac9f2c409     NaN
# 2cda9ab92b0f4dbfbe72e39a1bc26b9d7e41d28f     NaN
# 2db6ca9372c8585a0a894cef5c8be3c51a4547a7     NaN
# 4887dd8d4b582f6279c6f23114842d3fd071e62a     NaN
# 14a4c26acde03b2ebff1e1e84da29d60bc532410     NaN
# ...

# %%
commits_date = commits_url['commit.author.date']
commits_date
# Out:
# sha
# f332b5e6fcea965dc80f62220d7ee1457b04b90d    2019-03-07T15:49:16Z
# 4c048c3efc18cf9d50e34c76919c8049ee7f2dbd    2019-03-07T15:38:52Z
# 41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310    2019-01-18T18:28:33Z
# 750eb91e4535c14ec4bf03f60cb5756a1c93f68f    2019-01-17T21:59:35Z
# 4a8cc3cb64821cb58182a3a94be38f17d27a8e8f    2019-01-17T06:33:16Z
# 1501bac01f8183d223a47ca7f23649a5d98d7e00    2019-01-17T06:28:16Z
# 6c2a1247d4e13a37261081279f250ffa82ed5c96    2019-01-17T06:24:01Z
# cc02db3df76c8a16ecee3f7a937366ff427a7c3a    2019-01-16T23:20:01Z
# 49ba929952728ab17635591cf55137c8af01babb    2019-01-16T22:24:40Z
# ba93368ee5593b15c7b1829f82cbacb9a003476c    2019-01-16T22:24:35Z
# 2034c389cb81f30d30f94acc2a5237377d387dc1    2019-01-14T22:40:53Z
# 09cf3f0163fe3895128cb322f5450672435ede7e    2019-01-11T20:01:48Z
# 825dea0b3aab60bf587130441fab30d8abab775c    2019-01-10T21:15:16Z
# ced5e055e9313f60c57a7daab4ee89eac9f2c409    2019-01-10T21:11:31Z
# ...

# %%
import pandas as pd
import numpy as np
import datetime 
#commits_date = commits_date.loc['2018-12-04':'2014-08-15']
#commits_date
#import datetime 
#commits_date.loc[datetime.commit.author.date(year=2019,month=8,day=1):datetime.commit.author.date(year=2019,month=8,day=15)]
#commits_date
