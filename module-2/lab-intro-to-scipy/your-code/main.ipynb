# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
#import numpy and pandas

import pandas as pd
import numpy as np
import scipy
from scipy import stats
from scipy.stats import mode
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1 - The `stats` Submodule
#
# This submodule contains statistical functions for conducting hypothesis tests, producing various distributions and other useful tools. Let's examine this submodule using the KickStarter dataset. We will load the dataset below.

# %%
# Run this code:
kickstarter = pd.read_csv('../ks-projects-201801.csv')

# %% [markdown]
# Now print the `head` function to examine the dataset.

# %%
# Your code here:
kickstarter.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %% [markdown]
# Import the `mode` function from `scipy.stats` and find the mode of the `country` and `currency` column.

# %%
# Your code here:
kick_curr = kickstarter.currency.mode()
kick_curr
# Out:
# 0    USD
# dtype: object

# %%
kick_country = kickstarter.country.mode()
kick_country
# Out:
# 0    US
# dtype: object

# %% [markdown]
# The trimmed mean is a function that computes the mean of the data with observations removed. The most common way to compute a trimmed mean is by specifying a percentage and then removing elements from both ends. However, we can also specify a threshold on both ends. The goal of this function is to create a more robust method of computing the mean that is less influenced by outliers. SciPy contains a function called `tmean` for computing the trimmed mean.
#
# In the cell below, import the `tmean` function and then find the 75th percentile of the `goal` column. Compute the trimmed mean between 0 and the 75th percentile of the column. Read more about the `tmean` function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.tmean.html#scipy.stats.tmean).

# %%
# Your code here:

goal = kickstarter.goal
#goal_75 = np.percentile(goal, 75)
#goal_75
goal_75 = goal.quantile(0.75)
goal_75
goal_min = goal.min()
goal_min
# Out:
# 0.01

# %%
stats.tmean(goal,(goal_min, goal_75))
# Out:
# 4874.150287106898

# %% [markdown]
# #### SciPy contains various statistical tests. One of the tests is Fisher's exact test. This test is used for contingency tables.
#
# The test originates from the "Lady Tasting Tea" experiment. In 1935, Fisher published the results of the experiment in his book. The experiment was based on a claim by Muriel Bristol that she can taste whether tea or milk was first poured into the cup. Fisher devised this test to disprove her claim. The null hypothesis is that the treatments do not affect outcomes, while the alternative hypothesis is that the treatment does affect outcome. To read more about Fisher's exact test, click [here](https://en.wikipedia.org/wiki/Fisher%27s_exact_test).
#
# Let's perform Fisher's exact test on our KickStarter data. We intend to test the hypothesis that the choice of currency has an impact on meeting the pledge goal. We'll start by creating two derived columns in our dataframe. The first will contain 1 if the amount of money in `usd_pledged_real` is greater than the amount of money in `usd_goal_real`. We can compute this by using the `np.where` function. If the amount in one column is greater than the other, enter a value of 1, otherwise enter a value of zero. Add this column to the dataframe and name it `goal_met`.

# %%
# Your code here:

kickstarter.head()

kickstarter['goal_met'] = np.where(kickstarter.usd_pledged_real > kickstarter.usd_goal_real, 1, 0)
# Out:
#                 ID  My 2nd new column  goal_met  Fisher test  \
# 0       1000002330                  1         0            1
# 1       1000003930                  1         0            1
# 2       1000004038                  1         0            1
# 3       1000007540                  1         0            1
# 4       1000011046                  1         0            1
# 5       1000014025                  1         1            1
# 6       1000023410                  1         1            1
# 7       1000030581                  1         0            1
# 8       1000034518                  1         0            1
# 9        100004195                  1         0            1
# 10       100004721                  1         0            1
# 11       100005484                  1         1            1
# 12      1000055792                  1         0            1
# 13      1000056157                  1         0            1
# 14      1000057089                  1         1            1
# 15      1000064368                  1         0            1
# 16      1000064918                  1         0            1
# 17      1000068480                  1         0            1
# 18      1000070642                  1         0            1
# 19      1000071625                  1         0            1
# 20      1000072011                  1         1            1
# 21      1000081649                  1         0            1
# 22      1000082254                  1         0            1
# 23      1000087442                  1         0            1
# 24      1000091520                  1         1            1
# 25      1000102741                  1         1            1
# 26      1000103948                  1         0            1
# 27      1000104688                  1         1            1
# 28      1000104953                  1         1            1
# 29       100011318                  1         1            1
# ...            ...                ...       ...          ...
# 378631   999832803                  1         1            1
# 378632    99984851                  1         0            1
# 378633   999865831                  1         0            1
# 378634   999867839                  1         0            1
# 378635    99987261                  1         0            1
# 378636   999877902                  1         1            1
# 378637   999878813                  1         1            1
# 378638   999880710                  1         0            1
# 378639   999884445                  1         1            1
# 378640   999893629                  1         0            1
# 378641    99991751                  1         0            1
# 378642   999929142                  1         1            1
# 378643   999931480                  1         0            1
# 378644   999934908                  1         1            1
# 378645   999941823                  1         0            1
# 378646   999943841                  1         1            1
# 378647   999950812                  1         0            1
# 378648   999955533                  1         0            1
# 378649   999963618                  1         0            1
# 378650    99996661                  1         0            1
# 378651   999969812                  1         1            1
# 378652   999971898                  1         1            1
# 378653   999972264                  1         0            1
# 378654   999975836                  1         0            1
# 378655   999976312                  1         0            1
# 378656   999976400                  1         0            1
# 378657   999977640                  1         0            1
# 378658   999986353                  1         0            1
# 378659   999987933                  1         0            1
# 378660   999988282                  1         0            1
#
#                                                      name          category  \
# 0                         The Songs of Adelaide & Abullah            Poetry
# 1           Greeting From Earth: ZGAC Arts Capsule For ET    Narrative Film
# 2                                          Where is Hank?    Narrative Film
# 3       ToshiCapital Rekordz Needs Help to Complete Album             Music
# 4       Community Film Project: The Art of Neighborhoo...      Film & Video
# 5                                    Monarch Espresso Bar       Restaurants
# ...          ...         ...      ...     ...          ...               ...
# 378631  13861.50  successful      413      US     13861.50          13861.50
# 378632      0.00      failed        0      US         0.00              0.00
# 378633  11643.00      failed       97      US     11643.00          11643.00
# 378634   3531.00      failed       37      US      3531.00           3531.00
# 378635     70.00      failed        5      US        70.00             70.00
# 378636   5435.00  successful       78      CA      4814.88           4686.96
# 378637  10245.00  successful      123      US       145.00          10245.00
# 378638     18.00      failed        5      US        18.00             18.00
# 378639   5579.00  successful      103      US      5579.00           5579.00
# 378640    100.00    canceled        2      US       100.00            100.00
# 378641      0.00      failed        0      CH         0.00              0.00
# 378642   1246.00  successful       35      FR        66.72           1452.47
# 378643      0.00    canceled        0      US         0.00              0.00
# 378644   6169.00  successful      120      US      6169.00           6169.00
# 378645   2738.00      failed       38      GB      4281.15           4374.99
# 378646   1732.02  successful       31      US      1732.02           1732.02
# 378647    980.00      failed       16      US       980.00            980.00
# 378648    121.00    canceled        5      US       121.00            121.00
# 378649    135.00      failed        6      US        45.00            135.00
# 378650      0.00      failed        0      US         0.00              0.00
# 378651   5501.00  successful       78      CA      5019.92           4983.69
# 378652  21500.00  successful       36      NO      2698.97           2875.83
# 378653     25.00      failed        1      US        25.00             25.00
# 378654    154.00      failed        4      US         0.00            154.00
# 378655      0.00    canceled        0      CA         0.00              0.00
# 378656     25.00    canceled        1      US        25.00             25.00
# 378657    155.00      failed        5      US       155.00            155.00
# 378658     20.00      failed        1      US        20.00             20.00
# 378659    200.00      failed        6      US       200.00            200.00
# 378660    524.00      failed       17      US       524.00            524.00
#
#         usd_goal_real
# 0             1533.95
# 1            30000.00
# 2            45000.00
# 3             5000.00
# 4            19500.00
# 5            50000.00
# 6             1000.00
# 7            25000.00
# 8           125000.00
# 9            65000.00
# 10            2406.39
# 11           12500.00
# 12            5000.00
# 13          200000.00
# 14            6469.73
# 15            2500.00
# 16            1500.00
# 17            3000.00
# 18             250.00
# 19            5000.00
# 20           20000.00
# 21            2026.10
# 22            3500.00
# 23              65.55
# 24             175.00
# 25           10000.00
# 26           17489.65
# 27           15313.04
# 28             142.91
# 29           50000.00
# ...               ...
# 378631       10000.00
# 378632       12000.00
# 378633       25000.00
# 378634        4000.00
# 378635         800.00
# 378636        4311.83
# 378637       10000.00
# 378638        5000.00
# 378639        5000.00
# 378640        1000.00
# 378641       82207.27
# 378642        1165.70
# 378643        6500.00
# 378644        3500.00
# 378645       25566.05
# 378646         950.00
# 378647        4999.00
# 378648         500.00
# 378649         500.00
# 378650        6000.00
# 378651        4529.81
# 378652        2675.19
# 378653        1700.00
# 378654        6500.00
# 378655        4949.60
# 378656       50000.00
# 378657        1500.00
# 378658       15000.00
# 378659       15000.00
# 378660        2000.00
#
# [378661 rows x 18 columns]

# %% [markdown]
# Next, create a column that checks whether the currency of the project is in US Dollars. Create a column called `usd` using the `np.where` function where if the currency is US Dollars, assign a value of 1 to the row and 0 otherwise.

# %%
# Your code here:
kickstarter['usd'] = np.where(kickstarter.currency == 'USD', 1, 0)
kickstarter.head()
# Out:
#            ID  My 2nd new column  goal_met  Fisher test  \
# 0  1000002330                  1         0            1
# 1  1000003930                  1         0            1
# 2  1000004038                  1         0            1
# 3  1000007540                  1         0            1
# 4  1000011046                  1         0            1
#
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category currency    deadline     goal             launched  pledged  \
# 0    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28      0.0
# 1  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57   2421.0
# 2  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50    220.0
# 3         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11      1.0
# 4  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03   1283.0
#
#       state  backers country  usd pledged  usd_pledged_real  usd_goal_real  \
# 0    failed        0      GB          0.0               0.0        1533.95
# 1    failed       15      US        100.0            2421.0       30000.00
# 2    failed        3      US        220.0             220.0       45000.00
# 3    failed        1      US          1.0               1.0        5000.00
# 4  canceled       14      US       1283.0            1283.0       19500.00
#
#    usd
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1

# %% [markdown]
# Now create a contingency table using the `pd.crosstab` function in the cell below to compare the `goal_met` and `usd` columns.

# %%
usd = kickstarter['usd']
goal_met = kickstarter['goal_met']
pd.crosstab(usd, goal_met)
# Out:
# goal_met       0       1
# usd
# 0          58685   24611
# 1         187130  108235

# %% [markdown]
# Import the `fisher_exact` function from `scipy.stats` and conduct the hypothesis test on the contingency table that you have generated above. You can read more about the `fisher_exact` function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.fisher_exact.html#scipy.stats.fisher_exact). The output of the function should be the odds ratio and the p-value. The p-value will provide you with the outcome of the test.

# %%
# Your code here:
oddsratio, pvalue = stats.fisher_exact([[58685,24611], [187130, 108235]])
oddsratio, pvalue
#the p value, the probability is null for the null hypothesis so there is a correlation between the met goal and the currency in dollars.
# Out:
# (1.3791838163150314, 9.78e-321)

# %% [markdown]
# # Challenge 2 - The `linalg` submodule
#
# This submodule allows us to perform various linear algebra calculations.
#
# Using the solve function, find the solution of the equation system 5x + 2y = 3 and 3x + y = 2 in the cell below.

# %%
# Your code here:
from scipy.linalg import solve

#5x + 2y = 3 and 3x + y = 2
a = np.array([[5, 2], [3, 1]])
b = np.array([3, 2])
result = solve(a, b)
result
# Out:
# array([ 1., -1.])

# %% [markdown]
# # Challenge 3 - The `interpolate` submodule
#
# This submodule allows us to interpolate between two points and create a continuous distribution based on the observed data.
#
# In the cell below, import the `interp1d` function and first take a sample of 10 rows from `kickstarter`.

# %%
# Your code here:
from scipy.interpolate import interp1d
sample = kickstarter.sample(n=30)
sample
# Out:
#                 ID  My 2nd new column  goal_met  Fisher test  \
# 2596    1013369499                  1         0            1
# 19033   1096480689                  1         1            1
# 373369   972547626                  1         0            1
# 114341  1580740086                  1         0            1
# 144586  1734572592                  1         1            1
# 97074   1493121550                  1         0            1
# 92922   1472491011                  1         0            1
# 302106   608419679                  1         0            1
# 101607  1516347123                  1         0            1
# 249241   337736704                  1         0            1
# 253490    35919116                  1         0            1
# 309691   647337512                  1         1            1
# 262465    40503012                  1         0            1
# 175940  1894851409                  1         1            1
# 112691  1572434023                  1         0            1
# 368719   948525980                  1         0            1
# 364050   924893579                  1         0            1
# 89394   1454159003                  1         0            1
# 310395   651089658                  1         0            1
# 295398   573586625                  1         0            1
# 62090   1315715073                  1         0            1
# 89951   1456952571                  1         0            1
# 234337   261299587                  1         1            1
# 195323  1994775130                  1         1            1
# 102361  1520074992                  1         1            1
# 311998   659249261                  1         0            1
# 29786   1151387217                  1         1            1
# 50859   1258966152                  1         1            1
# 86773   1441210692                  1         0            1
# 90536   1459989423                  1         1            1
#
#                                                      name        category  \
# 2596    Don't go to Sleep: a story based on sleep para...          Horror
# 19033                                 Upshot - Short Film          Comedy
# 373369                                           Ukule-me           Music
# 114341                                        reviveTYRES        Footwear
# 144586                        Sterling Pickle Woodworking     Woodworking
# 97074                                Nina's Bakery by Kim          Events
# 92922                                   Braving The Storm     Documentary
# 302106  Custom World RISK board (Westeros, Hyrule, and...  Tabletop Games
# 101607  SpectorDance and MBARI present Ocean at the Sm...           Dance
# 249241                              an hour with John Doe    Film & Video
# 253490                             Dungeon Master Rebirth    Mobile Games
# 309691         Launch Santa Fe High School's Rocket Club!      Technology
# 262465    Help Make A Short Film About A Hit & Run Murder      Journalism
# 175940  Automated Discrimination: The Power and Peril ...        Academic
# 112691                                    Stay True Music           Faith
# 368719                   Oceanus -\tA game like no other.     Video Games
# 364050     JobFynd: The Must Have Super Cool Career Tool!            Apps
# 89394                   Producing "Disintegrating Houses"          Design
# 310395  Frame, the new IOS and Android application for...            Apps
# 295398                                        Rowan Croft           Farms
# 62090           ART: Eleven-Eleven - Minimal Watch Prints             Art
# 89951   Arctic Rain : Reduce swimming pool temperature...        Hardware
# 234337                    The Wreckage: Wearable Oddities          Crafts
# 195323  PAKMMA Fighting Alliance - A Different Kind of...          Shorts
# 102361            - HUDSON RIVER - A Wildlife Documentary     Documentary
# 311998           Batsh*t Bride - a Feature-Length Comedy!    Film & Video
# 29786          I'll Sing You Songs When You Aren't Around  Country & Folk
# 50859                                 The Premji Backpack  Product Design
# 86773   Photobooth unit and other profitable photograp...         Gadgets
# 90536                MSGA -- Junior Theater Festival 2015       Festivals
#
#        main_category currency    deadline      goal             launched  \
# 2596    Film & Video      USD  2014-09-17   15000.0  2014-08-18 22:12:10
# 19033   Film & Video      GBP  2016-05-06     300.0  2016-04-05 22:00:12
# 373369         Music      AUD  2014-09-11     250.0  2014-08-12 23:35:22
# 310395     220.00      failed        3      CH       109.70            219.17
# 295398       5.00      failed        1      US         5.00              5.00
# 62090      276.00      failed        6      GB        47.91            341.23
# 89951     1164.00      failed       19      US      1164.00           1164.00
# 234337     260.00  successful        9      CA       244.12            241.46
# 195323    1010.00  successful       15      US      1010.00           1010.00
# 102361   21846.00  successful       29      US     21846.00          21846.00
# 311998    3255.00      failed       30      US      3255.00           3255.00
# 29786     9810.00  successful      205      US      9810.00           9810.00
# 50859   126580.00  successful      937      US     14307.00         126580.00
# 86773        0.00      failed        0      GB         0.00              0.00
# 90536     1310.00  successful       15      US      1310.00           1310.00
#
#         usd_goal_real  usd
# 2596         15000.00    1
# 19033          434.76    0
# 373369         226.33    0
# 114341       16846.07    0
# 144586       14000.00    1
# 97074         3000.00    1
# 92922         2500.00    1
# 302106         614.02    0
# 101607        5000.00    1
# 249241        1100.00    1
# 253490      218400.22    0
# 309691        2500.00    1
# 262465        2000.00    1
# 175940        2000.00    1
# 112691        1000.00    1
# 368719       40000.00    1
# 364050       41862.02    0
# 89394        30000.00    1
# 310395      149432.16    0
# 295398       40000.00    1
# 62090         1811.24    0
# 89951         5000.00    1
# 234337         232.17    0
# 195323        1000.00    1
# 102361       20000.00    1
# 311998       25000.00    1
# 29786         7500.00    1
# 50859        30000.00    1
# 86773         2815.08    0
# 90536         1200.00    1

# %% [markdown]
# Next, create a linear interpolation of the backers as a function of `usd_pledged_real`. Create a function `f` that generates a linear interpolation of backers as predicted by the amount of real pledged dollars.
#
# Now create a new variable called x_new. This variable will contain all integers between the minimum number of backers in our sample and the maximum number of backers. The goal here is to take the dataset that contains few obeservations due to sampling and fill all observations with a value using the interpolation function.
# Hint: one option is the np.arange function.

# %%
# Your code here:
x = sample['usd_pledged_real']

y = sample['backers']
f = interp1d(x, y)

# %%
# Your code here:
backers_min = sample['backers'].min()
backers_min
backers_max = sample['backers'].max()
backers_max
# Out:
# 937

# %%
x_new = np.arange(backers_min, backers_max)

# %% [markdown]
# Plot function f for all values of `x_new`. Run the code below.

# %%
# Run this code:
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(x_new, f(x_new))

# %% [markdown]
# Next create a function that will generate a cubic interpolation function. Name the function `g`

# %%
# Your code here:
x2 = x
y2 = np.sin(y)
g = interp1d(x2, y2)

# %%
# Run this code:

plt.plot(x_new, g(x_new))

# %% [markdown]
# # Bonus Challenge - The Binomial Distribution
#
# The binomial distribution allows us to calculate the probability of k successes in n trials for a random variable with two possible outcomes (which we typically label success and failure).
#
# The probability of success is typically denoted by p and the probability of failure is denoted by 1-p.
#
# The `scipy.stats` submodule contains a `binom` function for computing the probabilites of a random variable with the binomial distribution. You may read more about the binomial distribution [here](https://en.wikipedia.org/wiki/Binomial_distribution) and about the `binom` function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.binom.html#scipy.stats.binom).
#
# In the cell below, compute the probability that a die lands on 5 exactly 3 times in 8 tries.
#
# Hint: the probability of rolling a 5 is 1/6.

# %%
# Your code here:
