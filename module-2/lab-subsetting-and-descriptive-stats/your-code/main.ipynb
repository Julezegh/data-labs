# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd
from urllib.request import urlopen
import json
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp= pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes

#in this case, we have two categorical columns and one float column
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
NewYork_temp = temp.loc[temp.State == 'New York']
NewYork_temp
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
NewYork_temp.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
above15 = temp.loc[temp.Temperature > 15]
above15
#temp[temp['Temperature'] == 'above15']
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp.loc[temp.Temperature > 15] ['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
city15_20 = temp.loc[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
city15_20
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %%
city15_20 = temp.loc[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)] ['City']
city15_20
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.describe()

temp_NY = temp.loc[temp.State == 'New York']
temp_NY.describe()
# Out:
#        Temperature
# count     3.000000
# mean     10.740741
# std       8.133404
# min       3.333333
# 25%       6.388889
# 50%       9.444444
# 75%      14.444444
# max      19.444444

# %%
temp_Conn = temp.loc[temp.State == 'Connecticut'].describe()
temp_Conn.describe()
# Out:
#        Temperature
# count     8.000000
# mean     12.370523
# std       6.465386
# min       1.964186
# 25%      11.333333
# 50%      15.486111
# 75%      16.006944
# max      17.222222

# %%
#temp_NJ = temp.loc[temp.State == 'New Jersey']
temp_NJ.describe()
# Out:
#        Temperature
# count     2.000000
# mean     21.111111
# std       1.571348
# min      20.000000
# 25%      20.555556
# 50%      21.111111
# 75%      21.666667
# max      22.222222

# %%
mean = temp.groupby('State').mean()
std = temp.groupby('State').std()
temps_3 = pd.concat([mean,std],axis = 1)
temps_3
# Out:
#              Temperature  Temperature
# State
# Connecticut    15.833333     1.964186
# New Jersey     21.111111     1.571348
# New York       10.740741     8.133404

# %%
#### Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('employee.csv')
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()

#as a guideline: most of employees earn more than 35 K (5 out of 9). 
#And regarding the seniority in the company, most of employees are working in the company for less than 6 years (6 out of 9).
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x120fee2b0>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
mean_salary = employee['Salary'].mean()
mean_salary
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
max_salary = employee['Salary'].max()
max_salary
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
min_salary = employee['Salary'].min()
min_salary
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
names = employee.loc[(employee.Salary == 30)]
names
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
David = employee.loc[employee.Name == 'David']
David
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
David['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
associate = employee.loc[employee.Title == 'associate'] & (employee.Salary > 55)
associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
associate_above55 = employee.loc[(employee.Title == 'associate') & (employee.Salary > 55)] 
associate_above55
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee
employee.groupby('Years').mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').mean()
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').mean() ['Salary']

#Yes, women are less payed than men and we are not satisfied.
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
mean_dpt = employee.groupby('Department').mean() ['Salary']
mean_dpt
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %%
min_dpt = employee.groupby('Department').min() ['Salary']
min_dpt
# Out:
# Department
# HR       30
# IT       30
# Sales    55
# Name: Salary, dtype: int64

# %%
max_dpt = employee.groupby('Department').max() ['Salary']
max_dpt
# Out:
# Department
# HR       70
# IT       70
# Sales    55
# Name: Salary, dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('orders.csv')
orders.columns
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'year', 'month', 'day', 'hour',
#        'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID',
#        'Country', 'amount_spent'],
#       dtype='object')

# %%
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# 5                5     536365     22752  2010     12    3     8
# 6                6     536365     21730  2010     12    3     8
# 7                7     536366     22633  2010     12    3     8
# 8                8     536366     22632  2010     12    3     8
# 9                9     536367     84879  2010     12    3     8
# 10              10     536367     22745  2010     12    3     8
# 11              11     536367     22748  2010     12    3     8
# 12              12     536367     22749  2010     12    3     8
# 13              13     536367     22310  2010     12    3     8
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
purchase_price = orders['UnitPrice'].mean() 
purchase_price
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
max_price = orders['UnitPrice'].max() 
max_price
# Out:
# 8142.75

# %%
# your answer here
min_price = orders['UnitPrice'].min() 
min_price
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
customers_Spain = orders.loc[orders.Country == 'Spain']
customers_Spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 13974        21565     538095     22504  2010     12    4    14
# 13975        21566     538095     22212  2010     12    4    14
# 13976        21567     538095     22953  2010     12    4    14
# 13977        21568     538095     84818  2010     12    4    14
# 13978        21569     538095     21114  2010     12    4    14
# 13979        21570     538095     84692  2010     12    4    14
# 13980        21571     538095     22796  2010     12    4    14
# 13981        21572     538095     40001  2010     12    4    14
# 13982        21573     538095     22646  2010     12    4    14
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
Count_cust_Spain = customers_Spain.groupby('CustomerID').count()
Count_cust_Spain.head()
# Out:
#             Unnamed: 0  InvoiceNo  StockCode  year  month  day  hour  \
# CustomerID
# 12354               58         58         58    58     58   58    58
# 12417               23         23         23    23     23   23    23
# 12421               45         45         45    45     45   45    45
# 12442               12         12         12    12     12   12    12
# 12445                4          4          4     4      4    4     4
#
#             Description  Quantity  InvoiceDate  UnitPrice  Country  \
# CustomerID
# 12354                58        58           58         58       58
# 12417                23        23           23         23       23
# 12421                45        45           45         45       45
# 12442                12        12           12         12       12
# 12445                 4         4            4          4        4
#
#             amount_spent
# CustomerID
# 12354                 58
# 12417                 23
# 12421                 45
# ...

# %%
len(Count_cust_Spain)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
qty50 = orders.loc[orders.Quantity > 50]
qty50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# 175            177     536386    85099B  2010     12    3     9
# 176            178     536387     79321  2010     12    3     9
# 177            179     536387     22780  2010     12    3     9
# 178            180     536387     22779  2010     12    3     9
# 179            181     536387     22466  2010     12    3     9
# 180            182     536387     21731  2010     12    3     9
# 215            217     536390    84970S  2010     12    3    10
# 217            219     536390     20668  2010     12    3    10
# 218            220     536390    85123A  2010     12    3    10
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
qty50_sp = customers_Spain.loc[customers_Spain.Quantity > 50] 
qty50_sp.head()
# Out:
#       Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250        6421     536944     22383  2010     12    5    12
# 4251        6422     536944     22384  2010     12    5    12
# 4252        6423     536944     20727  2010     12    5    12
# 4253        6424     536944     20725  2010     12    5    12
# 4254        6425     536944     20728  2010     12    5    12
#
#                   Description  Quantity          InvoiceDate  UnitPrice  \
# 4250  lunch bag suki  design         70  2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot       100  2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.        60  2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot        70  2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue       100  2010-12-03 12:20:00       1.45
#
#       CustomerID Country  amount_spent
# 4250       12557   Spain         115.5
# 4251       12557   Spain         145.0
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders = orders.loc[orders.amount_spent == 0]
free_orders.head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
# 29080       47068     540372     22090  2011      1    4    16
# 29082       47070     540372     22553  2011      1    4    16
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
# 29080       paper bunting retrospot        24  2011-01-06 16:41:00        0.0
# 29082        plasters in tin skulls        24  2011-01-06 16:41:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
lunch_bag = orders[orders['Description'].str.contains('lunch bag')]
lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# 361            370     536401     20726  2010     12    3    11
# 362            371     536401     22384  2010     12    3    11
# 402            411     536404     22383  2010     12    3    11
# 403            412     536404     20728  2010     12    3    11
# 404            413     536404     20727  2010     12    3    11
# 532            541     536412     20728  2010     12    3    11
# 533            542     536412     22382  2010     12    3    11
# 535            544     536412     22662  2010     12    3    11
# 536            545     536412     22383  2010     12    3    11
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
lunch_bag_2011 = lunch_bag.loc[lunch_bag.year == 2011]
lunch_bag_2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# 26861        43617     540098     22383  2011      1    2    15
# 26862        43618     540098     22382  2011      1    2    15
# 26863        43619     540098     20727  2011      1    2    15
# 26864        43620     540098     20727  2011      1    2    15
# 26902        43658     540099     20725  2011      1    2    16
# 26903        43659     540099     20726  2011      1    2    16
# 27118        44179     540157     22384  2011      1    3    11
# 27242        44329     540168     22383  2011      1    3    12
# 27360        44448     540176     22382  2011      1    3    12
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
orders['amount_spent'].hist()

# %%
orders.boxplot()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
aug_orders = orders.loc[orders.month == 8]
aug_orders.head()
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
#
#                               Description  Quantity          InvoiceDate  \
# 199475       6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476          scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart        24  2011-08-01 09:31:00
# 199478   single heart zinc t-light holder        12  2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder        12  2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
country_aug = Aug_orders.groupby('Country').mean()['Quantity']
country_aug
# Out:
# Country
# Australia          117.476636
# Austria              8.977273
# Belgium             10.664948
# Canada              10.400000
# Channel Islands     14.350000
# Denmark             21.125000
# EIRE                15.735245
# Finland             11.360656
# France              13.985940
# Germany             12.127044
# Iceland             12.590909
# Israel              17.707602
# Italy               12.073684
# Malta                6.945455
# Netherlands        106.700000
# Norway               8.259740
# Poland              10.941176
# Portugal            25.024390
# Spain                6.349206
# Sweden              32.850000
# Switzerland         11.228464
# United Kingdom      13.453019
# Unspecified          8.043478
# Name: Quantity, dtype: float64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
country_aug = Aug_orders.groupby('Country').mean()['Quantity']
country_aug
# Out:
# Country
# Australia          117.476636
# Austria              8.977273
# Belgium             10.664948
# Canada              10.400000
# Channel Islands     14.350000
# Denmark             21.125000
# EIRE                15.735245
# Finland             11.360656
# France              13.985940
# Germany             12.127044
# Iceland             12.590909
# Israel              17.707602
# Italy               12.073684
# Malta                6.945455
# Netherlands        106.700000
# Norway               8.259740
# Poland              10.941176
# Portugal            25.024390
# Spain                6.349206
# Sweden              32.850000
# Switzerland         11.228464
# United Kingdom      13.453019
# Unspecified          8.043478
# Name: Quantity, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
